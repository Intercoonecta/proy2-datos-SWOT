# %% [markdown]
# # Explorando los datos SWOT

# %%
import matplotlib
from matplotlib import pyplot as plt 
import matplotlib.gridspec as gridspec

import glob
import xarray as xr
import numpy as np
# import GriddedData

import numpy as np
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import xarray as xr
# https://docs.xarray.dev/en/stable/gallery.html
import datetime
import json
from erddapy import ERDDAP

# %%
dire = '/home/jovyan/shared/proyecto2/datos_SWOT/'

# %%
# !ls /home/jovyan/shared/proyecto2/datos_SWOT/
# Out:
# MED_1km_nogap_JAS12_swotFastPhase_BOX_c01_p009_v2.nc  fast_Med
# MED_fastPhase_1km_swotFAST_c01_p009.nc

# %% [markdown]
# # Explorando un unico fichero:

# %%
ds_c01_p009 = xr.open_dataset(dire + 'MED_fastPhase_1km_swotFAST_c01_p009.nc')

# %%
ds_c01_p009
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 1342, x_ac: 102)
# Coordinates:
#   * time        (time) timedelta64[ns] 05:51:29.000592 ... 05:54:56.998828800
#   * x_ac        (x_ac) float32 -60.0 -59.0 -58.0 -57.0 ... 57.0 58.0 59.0 60.0
# Data variables: (12/14)
#     lon_nadir   (time) float32 ...
#     lat_nadir   (time) float32 ...
#     lon         (time, x_ac) float32 ...
#     lat         (time, x_ac) float32 ...
#     x_al        (time) float32 ...
#     pd          (time, x_ac) float32 ...
#     ...          ...
#     roll_err    (time, x_ac) float32 ...
#     phase_err   (time, x_ac) float32 ...
#     SSH_model   (time, x_ac) float32 ...
#     pd_err_2b   (time, x_ac) float32 ...
#     bd_err      (time, x_ac) float32 ...
#     karin_err   (time, x_ac) float32 ...
# Attributes: (12/26)
#     corresponding_grid:        /Users/laura/src/git/swotsimulator/swotoutput/...
#     title:                     SWOT-like data simulated by SWOT simulator
# ...

# %% [markdown]
# De estas variables solo nos interesa lon, lat y ssh_model (los datos interpolados a la malla del satelite)

# %%
ds_c01_p009.SSH_model
# Out:
# <xarray.DataArray 'SSH_model' (time: 1342, x_ac: 102)>
# [136884 values with dtype=float32]
# Coordinates:
#   * time     (time) timedelta64[ns] 05:51:29.000592 ... 05:54:56.998828800
#   * x_ac     (x_ac) float32 -60.0 -59.0 -58.0 -57.0 ... 57.0 58.0 59.0 60.0
# Attributes:
#     units:      m
#     long_name:  SSH interpolated from model

# %%
# ds_c01_p009.SSH_model.plot()

# --> como las dimensiones y coordinadas no son las estandar, el plot de la funcion xarray por defecto da error

# %%
plt.figure(figsize=(14,6)) #(17,5)

ax1 = plt.subplot(111, projection=ccrs.PlateCarree())
ds_c01_p009.plot.scatter(x="lon", y="lat", hue="SSH_model", s=2, ax=ax1, transform=ccrs.PlateCarree())
# air.plot.contourf(ax=ax)
ax1.coastlines()
gl = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# %%
plt.figure(figsize=(14,6)) #(17,5)

ax1 = plt.subplot(111, projection=ccrs.PlateCarree())
plt.scatter(ds_c01_p009.lon, ds_c01_p009.lat, c=ds_c01_p009.SSH_model, s=2, transform=ccrs.PlateCarree())
# air.plot.contourf(ax=ax)
ax1.coastlines()
gl = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

plt.colorbar()

# %% [markdown]
# # Graficando una subzona de los datos sin tierra (sin islas en medio):

# %%
ds_c01_p009_caja = xr.open_dataset(dire + 'MED_1km_nogap_JAS12_swotFastPhase_BOX_c01_p009_v2.nc')

# %%
ds_c01_p009_caja
# Out:
# <xarray.Dataset>
# Dimensions:        (x_al: 200, x_ac: 102)
# Coordinates:
#   * x_al           (x_al) float32 1.397e+05 1.397e+05 ... 1.399e+05 1.399e+05
#   * x_ac           (x_ac) float32 -60.0 -59.0 -58.0 -57.0 ... 58.0 59.0 60.0
# Data variables:
#     lon_box        (x_al, x_ac) float32 ...
#     lat_box        (x_al, x_ac) float32 ...
#     ADT_model_box  (x_al, x_ac) float32 ...
#     ADT_obs_box    (x_al, x_ac) float32 ...
# Attributes:
#     description:   SWOT simulator 1 km grid resolution outputs are subsampled...
#     date_created:  Created Wed Apr 18 16:35:33 2018
#     author:        Laura Gomez Navarro (lauragomnav@gmail.com)
#     source:        SWOT simulator v2.21 outputs. File used: /Users/laura/src/...

# %% [markdown]
# De estas variables solo nos interesa lon, lat y ssh_model (los datos interpolados a la malla del satelite)

# %%
ds_c01_p009_caja.ADT_model_box
# Out:
# <xarray.DataArray 'ADT_model_box' (x_al: 200, x_ac: 102)>
# array([[-0.185407, -0.186427, -0.187391, ...,  0.004543,  0.002641,  0.000636],
#        [-0.186895, -0.18795 , -0.188941, ...,  0.002798,  0.00072 , -0.001442],
#        [-0.188323, -0.189429, -0.190419, ...,  0.001015, -0.001263, -0.003589],
#        ...,
#        [-0.075477, -0.076491, -0.077489, ..., -0.186207, -0.186345, -0.186453],
#        [-0.073756, -0.074688, -0.075584, ..., -0.186312, -0.186425, -0.1865  ],
#        [-0.072093, -0.072932, -0.073739, ..., -0.186373, -0.18646 , -0.186504]],
#       dtype=float32)
# Coordinates:
#   * x_al     (x_al) float32 1.397e+05 1.397e+05 ... 1.399e+05 1.399e+05
#   * x_ac     (x_ac) float32 -60.0 -59.0 -58.0 -57.0 ... 57.0 58.0 59.0 60.0
# Attributes:
#     units:      m
#     long_name:  Masked array of Absolute Dynamic Topography (ADT) interpolate...

# %%
ds_c01_p009_caja.ADT_model_box.plot()

# %%
plt.figure(figsize=(14,6)) #(17,5)

ax1 = plt.subplot(111, projection=ccrs.PlateCarree())
ds_c01_p009_caja.plot.scatter(x="lon_box", y="lat_box", hue="ADT_model_box", s=2, ax=ax1, transform=ccrs.PlateCarree())
# air.plot.contourf(ax=ax)
ax1.coastlines()
gl = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# %%
plt.figure(figsize=(14,6)) #(17,5)

ax1 = plt.subplot(111, projection=ccrs.PlateCarree())
plt.scatter(ds_c01_p009_caja.lon_box, ds_c01_p009_caja.lat_box, c=ds_c01_p009_caja.ADT_model_box, s=2, transform=ccrs.PlateCarree())
# air.plot.contourf(ax=ax)
ax1.coastlines()
gl = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

plt.colorbar()

# %% [markdown]
# # Probando datos HYCOM25:

# %%
ds_c01_p009_H = xr.open_dataset(dire + 'fast_Med/HYCOM25/HYCOM25_wmed_hourly_ASO_fast_c01_p009.nc')

# %%
ds_c01_p009_H
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 629, nC: 52, n2: 2)
# Dimensions without coordinates: time, nC, n2
# Data variables: (12/31)
#     time_sec                       (time) float64 ...
#     lon_nadir                      (time) float64 ...
#     lat_nadir                      (time) float64 ...
#     lon                            (time, nC) float64 ...
#     lat                            (time, nC) float64 ...
#     x_al                           (time) float32 ...
#     ...                             ...
#     roll_err                       (time, nC) float64 ...
#     phase_err                      (time, nC) float64 ...
#     ssh_model                      (time, nC) float64 ...
#     pd_err_2b                      (time, nC) float64 ...
#     bd_err                         (time, nC) float64 ...
#     karin_err                      (time, nC) float64 ...
# Attributes: (12/26)
#     description:               SWOT fixed grid
# ...

# %% [markdown]
# De estas variables solo nos interesa lon, lat y ssh_model (los datos interpolados a la malla del satelite)

# %%
ds_c01_p009_H.ssh_model
# Out:
# <xarray.DataArray 'ssh_model' (time: 629, nC: 52)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
# Dimensions without coordinates: time, nC
# Attributes:
#     valid_min:  -1500000
#     valid_max:  1500000
#     units:      m
#     long_name:  SSH interpolated from model

# %%
ds_c01_p009_H.ssh_model.plot()

# %%
plt.figure(figsize=(14,6)) #(17,5)

ax1 = plt.subplot(111, projection=ccrs.PlateCarree())
ds_c01_p009_H.plot.scatter(x="lon", y="lat", hue="ssh_model", s=2, ax=ax1, transform=ccrs.PlateCarree())
# air.plot.contourf(ax=ax)
ax1.coastlines()
gl = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# %%
plt.figure(figsize=(14,6)) #(17,5)

ax1 = plt.subplot(111, projection=ccrs.PlateCarree())
plt.scatter(ds_c01_p009_H.lon, ds_c01_p009_H.lat, c=ds_c01_p009_H.ssh_model, s=2, transform=ccrs.PlateCarree())
# air.plot.contourf(ax=ax)
ax1.coastlines()
gl = ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

plt.colorbar()
